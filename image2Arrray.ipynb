# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image
pic=Image.open('images/river.png')

# %%
# #trying with open cv
# import cv2
# img=cv2.imread('../images/apple.jpg',cv2.IMREAD_COLOR)
# cv2.imshow('apple',img)

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=347x145 at 0x208CB661250>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (145, 347, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red=pic_arr.copy()

# %%
pic_red.shape
# Out:
# (145, 347, 3)

# %%
plt.imshow(pic_red)

# %%
pic_red=pic_red[:,:,0]
plt.imshow(pic_red)

# %%
pic_green=pic_arr.copy()

# %%
# pic_green[:,:,1]=0

# %%
# pic_green[]
plt.imshow(pic_green[:,:,1],cmap='gray')

# %%
pic_green[:,:,1].shape
# Out:
# (145, 347)

# %%
picp=pic
picp
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=347x145 at 0x208CB661250>

# %%
ri=Image.open("images/river.png")
ri
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=347x145 at 0x208CE0EFF40>

# %%
picp=np.asarray(ri)

# %%
picp=picp.copy()

# %%
picp[:,:,0]=0
picp[:,:,1]=0

# %%
picp.shape
# Out:
# (145, 347, 3)

# %%
plt.imshow(picp)
