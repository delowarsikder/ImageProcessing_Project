# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image
pic=Image.open('images/river.png')

# %%
##trying with open cv
# import cv2
# img=cv2.imread('../images/apple.jpg',cv2.IMREAD_COLOR)
# cv2.imshow('apple',img)

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=347x145 at 0x208C7D625E0>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (145, 347, 3)

# %%
plt.imshow(pic_arr)
