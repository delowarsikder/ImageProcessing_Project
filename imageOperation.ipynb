# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
img=cv2.imread('images/river.png',cv2.IMREAD_COLOR)

# %%
###show image using cv2
# cv2.imshow("river",img)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (145, 347, 3)

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # gray_img.shape

# %%
plt.imshow(gray_img)

# %%
imgReshape=img=cv2.imread('images/river.png',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imgReshape,cmap='gray')

# %%
imgReshape.shape
# Out:
# (145, 347)

# %%
img_resize=cv2.resize(imgReshape,(100,100))

# %%
plt.imshow(img_resize,cmap='gray')

# %%
#resilze acconrding height and weight
w_ratio=0.8 #80% of original weight
h_ratio=0.7 #70% of original height

# %%
new_img=cv2.resize(img,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (102, 278)

# %%
##fliping a image
flipImg=cv2.flip(new_img,0)
cv2.imwrite("images/flip.png",flipImg)
plt.imshow(flipImg)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
##plot image to imcrease a size
fig=plt.figure(figsize=(100,2))
ax=fig.add_subplot(111)
ax.imshow(new_img)
new_img.shape
# Out:
# (102, 278)
